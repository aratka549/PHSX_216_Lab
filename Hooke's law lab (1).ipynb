# %% [markdown]
# # Method 1:  Determine k for spring 1 and 2

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([100,120,140,160,180,200])/1000
x1 = np.array([.335,.400,.465,.530,.595,.660])
errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'Small k spring','x(m)','F(N)','N/m')
#spring 2
m1 = np.array([100,120,140,160,180,200])/1000
x1 = np.array([9,10.5,12,14,15.5,17])/100
errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'Large k spring','x(m)','F(N)','N/m')
# Out:
# Slope = 3.02 N/m
# Error in slope = 0.04 N/m
# Goodness of fit = 0.00
# Slope = 12.01 N/m
# Error in slope = 0.14 N/m
# Goodness of fit = 12.90

# %% [markdown]
# # Method 2: Determine K for spring 1 and 2

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([.81,.85,.888,.90,.96,.99])**2
x1 = np.array([200,220,240,260,280,300])/1000
errm = np.array([.0287,.034,.0355,.036,.0387,.0396])

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1,errm,'large k spring','M(kg)','T^2','Nm')

m1 = np.array([.81,.95,1.07,1.19,1.26,1.41])**2
x1 = np.array([50,70,90,110,130,150])/1000
errm = np.array([.0276,.038,.0428,.0476,.0504,.0564])

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1,errm,'Small k spring','M(kg)','T^2','Nm')
# Out:
# Slope = 3.23 Nm
# Error in slope = 0.41 Nm
# Goodness of fit = 1.18
# Slope = 13.12 Nm
# Error in slope = 0.49 Nm
# Goodness of fit = 5.33
